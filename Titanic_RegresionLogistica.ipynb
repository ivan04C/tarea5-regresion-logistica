# %% [markdown]
# # 1. Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc

# %% [markdown]
# # importe de librerias

# %%
#Cargar las librerias necesrias

import pandas as pd # Manejo y análisis de estructuras de datos
import numpy as np # Cálculo numérico y el análisis de datos
import seaborn as sns # Creación gráficos estadísticos
import matplotlib.pyplot as plt # Creación de gráficos en dos dimensiones

# librerías de para implementar modelos de ciencia de datos
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LinearRegression -> Librería para Regresión Lineal
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # cargar todos los datos

# %%
# lectura de datos en Python y lo cargamos en la variable Datos

DataFrame1 = pd.read_csv('D:/Documents/ingenieria de sistemas ivan castro/SEXTO SEMESTRE/Analisis de Datos/actividad 5/Titanic-Dataset.csv')

# %%
# Muestra las primeras filas del DataFrame para verificar que se ha cargado correctamente
DataFrame1.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# # obtener informacion sobre las variables en conjunto de datos

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(DataFrame1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# se muestra un histograma para observar los datos agregados 
DataFrame1.hist(figsize =(20,13))
plt.show()

# %%
# muestra la descripcion de los datos 
DataFrame1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# seleccionar los datos de tipo float64 y int 64 
# Seleccionar solo las columnas numéricas
datos_numericos = DataFrame1.select_dtypes(include=['float64', 'int64'])

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['Survived'])
plt.title('Identificación de Datos Faltantes y Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos')

# %%
# Identificar valores atípicos

plt.figure(figsize=(12, 6))
sns.boxplot(data = datos_numericos  )
plt.title('Diagrama de caja de variables numéricas')
plt.xticks(rotation=45)
plt.show()

# %%
# Identificar valores atípicos

plt.figure(figsize=(4, 4))
sns.boxplot(x= datos_numericos['Survived']  )
plt.title('datos faltantes en Survived',fontsize=10)
plt.show()

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'Name', y = 'Survived', data = DataFrame1)
plt.subplot(2,3,2)
sns.boxplot(x = 'Sex', y = 'Survived', data = DataFrame1)
plt.subplot(2,3,3)
sns.boxplot(x = 'Ticket', y = 'Survived', data = DataFrame1)
plt.subplot(2,3,4)
sns.boxplot(x = 'Cabin', y = 'Survived', data = DataFrame1)
plt.subplot(2,3,5)
sns.boxplot(x = 'Embarked', y = 'Survived', data = DataFrame1)

plt.show()

# %% [markdown]
# # 2 Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#ver que datos faltantes hay
print("PassengerId: ",DataFrame1['PassengerId'].isin([0]).sum())
print("Survived: ",DataFrame1['Survived'].isin([0]).sum())
print("Pclass: ",DataFrame1['Pclass'].isin([0]).sum())
print("Name: ",DataFrame1['Name'].isin([0]).sum())
print("Sex: ",DataFrame1['Sex'].isin([0]).sum())
print("Age: ",DataFrame1['Age'].isin([0]).sum())
print("SibSp: ",DataFrame1['SibSp'].isin([0]).sum())
print("Parch: ",DataFrame1['Parch'].isin([0]).sum())
print("Ticket: ",DataFrame1['Ticket'].isin([0]).sum())
print("Parch: ",DataFrame1['Parch'].isin([0]).sum())
print("Fare: ",DataFrame1['Fare'].isin([0]).sum())
print("Cabin: ",DataFrame1['Cabin'].isin([0]).sum())
print("Embarked: ",DataFrame1['Embarked'].isin([0]).sum())
# Out:
# PassengerId:  0
# Survived:  549
# Pclass:  0
# Name:  0
# Sex:  0
# Age:  0
# SibSp:  608
# Parch:  678
# Ticket:  0
# Parch:  678
# Fare:  15
# Cabin:  0
# Embarked:  0

# %%
# Reemplazar todos los ceros con el valor medio (promedio) de la columna.

DataFrame1['Survived']=DataFrame1['Survived'].replace(0,DataFrame1['Survived'].mean())
DataFrame1['SibSp']=DataFrame1['SibSp'].replace(0,DataFrame1['SibSp'].mean())
DataFrame1['Parch']=DataFrame1['Parch'].replace(0,DataFrame1['Parch'].mean())
DataFrame1['Fare']=DataFrame1['Fare'].replace(0,DataFrame1['Fare'].mean())

# %%
#ver que datos faltantes hay
print("PassengerId: ",DataFrame1['PassengerId'].isin([0]).sum())
print("Survived: ",DataFrame1['Survived'].isin([0]).sum())
print("Pclass: ",DataFrame1['Pclass'].isin([0]).sum())
print("Name: ",DataFrame1['Name'].isin([0]).sum())
print("Sex: ",DataFrame1['Sex'].isin([0]).sum())
print("Age: ",DataFrame1['Age'].isin([0]).sum())
print("SibSp: ",DataFrame1['SibSp'].isin([0]).sum())
print("Parch: ",DataFrame1['Parch'].isin([0]).sum())
print("Ticket: ",DataFrame1['Ticket'].isin([0]).sum())
print("Parch: ",DataFrame1['Parch'].isin([0]).sum())
print("Fare: ",DataFrame1['Fare'].isin([0]).sum())
print("Cabin: ",DataFrame1['Cabin'].isin([0]).sum())
print("Embarked: ",DataFrame1['Embarked'].isin([0]).sum())
# Out:
# PassengerId:  0
# Survived:  0
# Pclass:  0
# Name:  0
# Sex:  0
# Age:  0
# SibSp:  0
# Parch:  0
# Ticket:  0
# Parch:  0
# Fare:  0
# Cabin:  0
# Embarked:  0

# %%
# IDENTIFICAR DATOS ATIPICOS EN LAS VARIABLES O COLUMNAS 


# Calcula el rango intercuartílico (IQR) para cada columna
Q1 = datos_numericos.quantile(0.25)
Q3 = datos_numericos.quantile(0.75)
IQR = Q3 - Q1

# Define un criterio para identificar valores atípicos
valores_atipicos = (datos_numericos < (Q1 - 1.5 * IQR)) | (datos_numericos > (Q3 + 1.5 * IQR))

# Cuenta la cantidad de valores atípicos en cada columna
valoresatipicos_count = valores_atipicos.sum()
print("Cantidad de valores atípicos en cada columna:")
print(valoresatipicos_count)
# Out:
# Cantidad de valores atípicos en cada columna:
# PassengerId      0
# Survived         0
# Pclass           0
# Age             11
# SibSp           46
# Parch          213
# Fare           116
# dtype: int64

# %%
# Identificar valores atípicos

plt.figure(figsize=(6, 6))
sns.boxplot(x= DataFrame1['Survived']  )
plt.title('datos faltantes en Survived',fontsize=10)
plt.show()

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 4 to 667
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  194 non-null    int64
#  1   Survived     194 non-null    float64
#  2   Pclass       194 non-null    int64
#  3   Name         194 non-null    object
#  4   Sex          194 non-null    object
#  5   Age          133 non-null    float64
#  6   SibSp        194 non-null    float64
#  7   Parch        194 non-null    float64
#  8   Ticket       194 non-null    object
#  9   Fare         194 non-null    float64
#  10  Cabin        2 non-null      object
#  11  Embarked     194 non-null    object
#  12  binario      194 non-null    int32
# dtypes: float64(5), int32(1), int64(2), object(5)
# memory usage: 20.5+ KB

# %% [markdown]
# # 3 Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características.

# %%
# Total de personas con Diabetes

DataFrame1['Survived'].value_counts()
# Out:
# Survived
# 0.383838    549
# 1.000000    342
# Name: count, dtype: int64

# %%
# muestra si hay datos NaN en la variable x 
nan_values_X = X.isna().sum()
print("Valores NaN en las características seleccionadas (X):")
print(nan_values_X)
# Out:
# Valores NaN en las características seleccionadas (X):
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
#               ...
# Cabin_G6         0
# Cabin_T          0
# Embarked_C       0
# Embarked_Q       0
# Embarked_S       0
# Length: 1731, dtype: int64

# %%
DataFrame1[['Survived']].head(40)
# Out:
#     Survived
# 0   0.383838
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   0.383838
# 5   0.383838
# 6   0.383838
# 7   0.383838
# 8   1.000000
# 9   1.000000
# 10  1.000000
# 11  1.000000
# 12  0.383838
# 13  0.383838
# 14  0.383838
# 15  1.000000
# 16  0.383838
# 17  1.000000
# 18  0.383838
# 19  1.000000
# 20  0.383838
# 21  1.000000
# 22  1.000000
# 23  1.000000
# 24  0.383838
# 25  1.000000
# 26  0.383838
# 27  0.383838
# 28  1.000000
# 29  0.383838
# 30  0.383838
# 31  1.000000
# 32  1.000000
# 33  0.383838
# 34  0.383838
# 35  0.383838
# 36  1.000000
# 37  0.383838
# 38  0.383838
# 39  1.000000

# %%
datos_codificados = pd.get_dummies(DataFrame1, columns=['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'])
#PassengerId: Identificador único de cada pasajero.

# %%
# analisis de correlacion
      
correlacion = datos_codificados.corr()
plt.figure(figsize =(12,8))
sns.heatmap(correlacion, annot = True, cmap ='coolwarm', fmt =".2f")
plt.title('Matriz de correlacion')
plt.show()

# %%
#verificar que variables tienen mas correlaciones
correlacion_variableobjetivo = correlacion['Survived'].abs().sort_values(ascending = False)
variables_mascorrelacionadas = correlacion_variableobjetivo[1:]
print(variables_mascorrelacionadas)
# Out:
# Sex_male                  0.543351
# Sex_female                0.543351
# Pclass                    0.338481
# Fare                      0.251092
# Embarked_C                0.168240
#                             ...
# Ticket_S.C./PARIS 2079    0.011329
# Ticket_371110             0.006036
# Cabin_C22 C26             0.006036
# PassengerId               0.005007
# Embarked_Q                0.003650
# Name: Survived, Length: 1730, dtype: float64

# %%
# Binarización
umbral = 0.5
datos_codificados['binario'] = (datos_codificados['Survived'] >= umbral).astype(int)

# %%
# muestra si hay datos NaN en la variable x 
nan_values_X = X.isna().sum()
print("Valores NaN en las características seleccionadas (X):")
print(nan_values_X)
# Out:
# Valores NaN en las características seleccionadas (X):
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
#               ...
# Cabin_G6         0
# Cabin_T          0
# Embarked_C       0
# Embarked_Q       0
# Embarked_S       0
# Length: 1731, dtype: int64

# %%
# muestra si hay datos NaN en la variable x 
nan_values_y = y.isna().sum()
print("Valores NaN en la variable objetivo (y):")
print(nan_values_y)
# Out:
# Valores NaN en la variable objetivo (y):
# 0

# %% [markdown]
# # 4. Dividir el dataset en Train y Test para evaluar correctamente el modelo.

# %%
# Porcentaje de datos para entrenamiento (train) = 75% , y para prueba (test) = 25%

# Se crean variables X y Y para almacenar la información del entrenamiento

X = datos_codificados.drop('binario',axis=1) # Se cargan los datos de train sin los datos de la columna Diabetico 
Y = datos_codificados['binario'] # Se cargan los datos de train con los datos de la la columna Diabetico

#La función train_test_split crea una división de un conjunto de datos en dos bloques uno de entrenamiento y otro de prueba (train and test)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state= 0)

# %%
print("Conjunto de entrenamiento - Características (X_train):")
print (X_train)
# Out:
# Conjunto de entrenamiento - Características (X_train):
#      PassengerId  Survived  Pclass   Age     SibSp     Parch     Fare  \
# 671          672  0.383838       1  31.0  1.000000  0.381594  52.0000
# 417          418  1.000000       2  18.0  0.523008  2.000000  13.0000
# 634          635  0.383838       3   9.0  3.000000  2.000000  27.9000
# 323          324  1.000000       2  22.0  1.000000  1.000000  29.0000
# 379          380  0.383838       3  19.0  0.523008  0.381594   7.7750
# ..           ...       ...     ...   ...       ...       ...      ...
# 131          132  0.383838       3  20.0  0.523008  0.381594   7.0500
# 490          491  0.383838       3   NaN  1.000000  0.381594  19.9667
# 528          529  0.383838       3  39.0  0.523008  0.381594   7.9250
# 48            49  0.383838       3   NaN  2.000000  0.381594  21.6792
# 80            81  0.383838       3  22.0  0.523008  0.381594   9.0000
#
#      Name_Abbing, Mr. Anthony  Name_Abbott, Mr. Rossmore Edward  \
# ...

# %%
print("\nConjunto de entrenamiento - Variable objetivo (y_train):")
print(y_train)
# Out:
# Conjunto de entrenamiento - Variable objetivo (y_train):
# 105    0
# 68     1
# 253    0
# 320    0
# 706    1
#       ..
# 835    1
# 192    1
# 629    0
# 559    1
# 684    0
# Name: Survived, Length: 668, dtype: int64

# %%
print("\nConjunto de prueba - Características (X_test):")
print(X_test)
# Out:
# Conjunto de prueba - Características (X_test):
#      PassengerId  Survived  Pclass   Age     SibSp     Parch       Fare  \
# 288          289  1.000000       2  42.0  0.523008  0.381594  13.000000
# 869          870  1.000000       3   4.0  1.000000  1.000000  11.133300
# 182          183  0.383838       3   9.0  4.000000  2.000000  31.387500
# 684          685  0.383838       2  60.0  1.000000  1.000000  39.000000
# 599          600  1.000000       1  49.0  1.000000  0.381594  56.929200
# ..           ...       ...     ...   ...       ...       ...        ...
# 882          883  0.383838       3  22.0  0.523008  0.381594  10.516700
# 434          435  0.383838       1  50.0  1.000000  0.381594  55.900000
# 304          305  0.383838       3   NaN  0.523008  0.381594   8.050000
# 500          501  0.383838       3  17.0  0.523008  0.381594   8.662500
# 633          634  0.383838       1   NaN  0.523008  0.381594  32.204208
#
# ...

# %%
print("\nConjunto de prueba - Variable objetivo (y_test):")
print(y_test.head())
# Out:
# Conjunto de prueba - Variable objetivo (y_test):
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
# Name: Survived, dtype: int64

# %%
# eliminar datos NAN EN X_TEST Y X_TRAIN 

from sklearn.impute import SimpleImputer

# Crear un imputador
imputer = SimpleImputer(strategy='mean')

# Aplicar la imputación a las características de entrada
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# # 5. Entrenar el modelo configurando los diferentes hiperparámetros

# %%
# Construir el modelo de regresión logística 

modelo_regresion = LogisticRegression(solver = "liblinear") # liblinear es una libreria para resolver problemas lineales de clasificación y regresión
modelo_regresion.fit(X_train,Y_train)

# Crea el modelo de prediccion
Prediccion = modelo_regresion.predict(X_test) # la función predict predice los valores a partir del conjunto de datos de validación

# %%
print (y_test)
# Out:
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
#       ..
# 167    0
# 306    1
# 379    0
# 742    1
# 10     1
# Name: Survived, Length: 223, dtype: int64

# %%
print(prediccion)
# Out:
# [-0.13298059  0.05921575 -0.08052322  0.900454    0.81112717  0.31003844
#   0.88235463  0.9848255   0.35440447  0.60557377  0.21707317  0.79141436
#   0.16238373  0.68553003  0.94798825  0.59285047  0.04990364  0.59941872
#   0.18044827  0.26601622  0.14629204  0.6723553   0.16238373  0.3851303
#   0.60437948  1.1233464   0.26572205  0.60437948  0.81476423  0.37168098
#   0.10502214  0.68011224  0.02606922  0.51399184  0.21510482  0.58172553
#   0.0065629   0.13619627  0.13652416  0.19100445  0.47571905  0.07456474
#   0.05921575 -0.00836637  0.91636512  0.05921575  0.05921575  0.82237045
#   0.23600208  0.53562767  0.31003844  0.46063802  1.00891889  0.12099513
#   0.37521923  0.04836173  0.3127139   0.23629266 -0.18981545  0.27097201
#   0.18838303  0.31184362  0.90615968  0.38006514  1.00390762  0.37417767
#   0.87630331  0.30407155  0.94778424  0.85370812  0.66344248  0.53754208
#   0.40818906  0.05921575  0.10696253  0.36846921  0.3482105   0.48592539
# ...

# %% [markdown]
# # 6. Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc

# %%
# Desempeño del modelo de regresión

print(classification_report(Y_test,Prediccion))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       137
#            1       1.00      1.00      1.00        86
#
#     accuracy                           1.00       223
#    macro avg       1.00      1.00      1.00       223
# weighted avg       1.00      1.00      1.00       223

# %% [markdown]
# # 7. Realizar las diferentes gráficas que permitan visualizar los resultados del modelo.

# %%
#Matrix de Confusión del modelo

cm=confusion_matrix(Y_test,Prediccion)
disp=metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
# Curva de precisón del modelo

from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(Y_test, Prediccion)
plt.show()
